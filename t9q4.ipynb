# %% [markdown]
# # EE2211 Tutorial 9
#
# ### by Chua Dingjuan (Oct 2022)

# %% [markdown]
# ## Question 4 Python Codes

# %% [markdown]
# ### 4(a)Split the database into two sets: 80% of samples for training, and 20% of samples for testing using random_state=0

# %% [markdown]
# ### 4(b)Train a decision tree classifier (i.e., “tree.DecisionTreeClassifier” from sklearn) using the training set with a maximum depth of 4 based on the “entropy” criterion.

# %%
from sklearn.datasets import load_iris
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

iris_dataset = load_iris()

## (a) split data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
iris_dataset['data'], iris_dataset['target'], test_size=0.2, random_state=0)

y_train.shape
y_train=y_train.reshape((len(y_train),1))

##--- USING SKLEARN ----##

#Using decision tree in sklearn
from sklearn.tree import DecisionTreeClassifier

#Creating an object called tree and applying it to training data
tree = DecisionTreeClassifier(criterion='entropy', max_depth=4)
tree.fit(X_train, y_train)

#Calculating predicted y values for xtrain values
y_pred_train = tree.predict(X_train)
y_pred_test =  tree.predict(X_test)

# %% [markdown]
# ### 4(c) Compute the training and test accuracies. You can use accuracy_score from sklearn.metrics for accuracy computation

# %%
#Calculating accuracy scores
score_train = accuracy_score(y_train, y_pred_train)
score_test = accuracy_score(y_test, y_pred_test)
print('Training accuracy score :',score_train)
print('Testing accuracy score :',score_test)
# Out:
# Training accuracy score : 0.9916666666666667
# Testing accuracy score : 1.0

# %% [markdown]
# ### 4(d) Plot the tree using “tree.plot_tree”.

# %%
#Plotting decision tree using plot_tree function
from sklearn.tree import plot_tree

plot_tree(tree)
plt.show()
